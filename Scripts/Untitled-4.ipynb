# %%
import pandas as pd
from pandas import json_normalize
from pathlib import Path
from sqlalchemy import create_engine, text
import os
import json

engine_DEV_Test = create_engine(
    "mssql+pyodbc://sa:Jesus&411@Dev-Test/BCDA_Data?driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
df = pd.read_sql_query(text("select * from eob_basetable"), con = engine_DEV_Test)
df.head()
# Out:
#               Claim_ID  claim_group  Patient_ID  clm_type_cd  \
# 0  carrier-33451174990  35366366483    58594950           71
# 1  carrier-33583729097  35753417356    47507798           71
# 2  carrier-33599915381  35773087785    97356385           71
# 3  carrier-33625713536  35826919127   385686953           71
# 4  carrier-33641185603  35834195122    57984040           71
#
#                                     clm_type_display eob_type      clm_type  \
# 0  Local carrier non-durable medical equipment, p...  CARRIER  professional
# 1  Local carrier non-durable medical equipment, p...  CARRIER  professional
# 2  Local carrier non-durable medical equipment, p...  CARRIER  professional
# 3  Local carrier non-durable medical equipment, p...  CARRIER  professional
# 4  Local carrier non-durable medical equipment, p...  CARRIER  professional
#
#       status billablePeriod_start billablePeriod_end  ... admitting_dgns  \
# ...

# %%
df_carrier = df[(df['eob_type']== 'CARRIER') & (df['payment_amount_value']>250) & (df['status']!= 'cancelled')]
df_carrier.sort_values(by = 'payment_amount_value', ascending = False)
# Out:
#                    Claim_ID  claim_group  Patient_ID  clm_type_cd  \
# 36353   carrier-34900736936  39517818808   364444462           71
# 88600   carrier-34998229400  39297397911    99501349           71
# 124070  carrier-35097549723  40023123954    99501349           71
# 133732  carrier-35115462725  40019431154   364444462           71
# 124071  carrier-35097549724  40020238954    99501349           71
# ...                     ...          ...         ...          ...
# 127567  carrier-35102818472  39524316348   307214761           71
# 54324   carrier-34940717828  39609950537    71230047           71
# 99566   carrier-35024811968  39189001945   435874769           71
# 60189   carrier-34952529991  39019886159    40654473           71
# 130838  carrier-35107980214  40018352314   530559035           71
#
#                                          clm_type_display eob_type  \
# 36353   Local carrier non-durable medical equipment, p...  CARRIER
# ...

# %%
df[df['payment_amount_value']>= 0].groupby('eob_type').agg({
    'payment_amount_value': ['mean', 'median', 'min', 'max']
})
# Out:
#            payment_amount_value
#                            mean    median  min        max
# eob_type
# CARRIER              107.829951     53.09  0.0   32076.83
# DME                  213.012590     76.96  0.0   19635.44
# HHA                 1675.829844   1600.92  0.0    4595.57
# HOSPICE             4124.767290   4686.65 -0.0   11032.20
# INPATIENT          15296.076373  11785.90 -0.0  126008.52
# OUTPATIENT           737.680492    111.75  0.0   71323.91
# SNF                 8483.536821   8433.56 -0.0   36742.16

# %%
df['billablePeriod_start'] = pd.to_datetime(df['billablePeriod_start'])
df['billablePeriod_end'] = pd.to_datetime(df['billablePeriod_end'])

df['los'] = (df['billablePeriod_end'] - df['billablePeriod_start']).dt.days

# %%
df.to_json('eob_data.json', orient = 'records', lines = True)

# %%
df

# %%
import os 
from pathlib import Path


dir_onedrive = next(p for p in Path(os.environ["USERPROFILE"]).iterdir()
                if p.name.startswith("OneDrive - "))

path = Path(
    dir_onedrive
)

parts=[]
for file in path.rglob('*.sql'):
    parts.append(str(file).rsplit('\\',1))

sorted(parts, key=lambda x: (x[0], x[1]))
# Out:
# [['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com',
#   'LDFLogFileShrink.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com',
#   'Test_consecutive_job.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com', 'add_jobs_Script.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com\\Documentation\\ERRORS',
#   'RecoveryPending.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com\\Documentation\\Valerie Chrome Profile\\Valerie Data From local\\Python\\Reports',
#   'ACODoctor_RiskScore.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com\\Documentation\\Valerie Chrome Profile\\Valerie Data From local\\Python\\Reports',
#   'ACO_Beneficiaries_AvgRiskScore.sql'],
#  ['C:\\Users\\Levi_\\OneDrive - primecaremanagers.com\\Documentation\\Valerie Chrome Profile\\Valerie Data From local\\Python\\Reports',
#   'ACO_Beneficiaries_CountByAttributionType.sql'],
# ...

# %%
import requests 

data = requests.post(r'https://api.restful-api.dev/objects', json={"name": "Levi", "data": "This is an object"}  ).json()
object_id = data.get('id')
df = requests.get(r'https://api.restful-api.dev/objects/' + object_id).json()
df
# Out:
# {'id': 'ff8081819d82fab6019de4e4e5eb7377',
#  'name': 'Levi',
#  'data': 'This is an object'}

# %%
import os 
from pathlib import Path
