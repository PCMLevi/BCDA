# %%
from sqlalchemy import create_engine
import pandas as pd

engine_DEV_Test = create_engine(
    "mssql+pyodbc://sa:Jesus&411@Dev-Test/CCLF_Lookuptables?driver=ODBC+Driver+17+for+SQL+Server", fast_executemany=True
)

df = pd.read_csv(r"C:\Users\Levi_\Downloads\clia_listing1778699859497.csv", sep=',', encoding="cp1252")
df
# Out:
#        CLIA ID Number                                      Facility Name  \
# 0          50D2262364               01 BRIARWOOD SENIOR FAMILY HOME LLC
# 1          26D2154305  1000 LANDING CIRCLE OPCO LLC D/B/A VERO OF O'F...
# 2          25D0677044                       1001 HOSPITAL ROAD OPCO LLC
# 3          10D2040064                                     1001 SURGICAL
# 4          45D2194489                                         1003 ABBY
# ...               ...                                                ...
# 301029     03D2314823                            ZYNERGY SKIN + MED SPA
# 301030     21D2213979                   ZYNITH HEALTH CARE & ASSOCIATES
# 301031     45D2337819                      ZYRIX CLINICAL RESEARCH, LLC
# 301032     11D2156374                                        ZYWIE, INC
# 301033     06D2166216                              ZZAP PEDIATRICS, LLC
#
#               Lab Director                          Address           City  \
# ...

# %%
import pandera as pa
from pandera import Column, DataFrameSchema


df['Certificate Effective Date'] = pd.to_datetime(df['Certificate Effective Date'])

schema = DataFrameSchema({
    'CLIA ID Number': Column(pa.String),
    'Certificate Effective Date': Column(pa.DateTime)
})
try:
    schema.validate(df, lazy = True)
except pa.errors.SchemaErrors as e:
    print(e.failure_cases)

# %%
df.dtypes
# Out:
# CLIA ID Number                         object
# Facility Name                          object
# Lab Director                           object
# Address                                object
# City                                   object
# State                                  object
# Zip Code                               object
# Phone                                  object
# Certificate Effective Date     datetime64[ns]
# Certificate Expiration Date            object
# Certificate Type                       object
# Accrediting Organization               object
# Facility Type                          object
# dtype: object

# %%
df
# Out:
#        CLIA ID Number                                      Facility Name  \
# 0          50D2262364               01 BRIARWOOD SENIOR FAMILY HOME LLC
# 1          26D2154305  1000 LANDING CIRCLE OPCO LLC D/B/A VERO OF O'F...
# 2          25D0677044                       1001 HOSPITAL ROAD OPCO LLC
# 3          10D2040064                                     1001 SURGICAL
# 4          45D2194489                                         1003 ABBY
# ...               ...                                                ...
# 301029     03D2314823                            ZYNERGY SKIN + MED SPA
# 301030     21D2213979                   ZYNITH HEALTH CARE & ASSOCIATES
# 301031     45D2337819                      ZYRIX CLINICAL RESEARCH, LLC
# 301032     11D2156374                                        ZYWIE, INC
# 301033     06D2166216                              ZZAP PEDIATRICS, LLC
#
#               Lab Director                          Address           City  \
# ...
